# %%
import pandas as pd
from google.colab import drive
# !pip install pandasql
from pandasql import sqldf

drive.mount('/content/drive')

path_to_folder = '/content/drive/MyDrive/Case_GlobaS/'

df_accounts = pd.read_json(path_to_folder + "accounts_anonymized.json")
df_cases = pd.read_json(path_to_folder + "support_cases_anonymized.json")
# Out:
# Requirement already satisfied: pandasql in /usr/local/lib/python3.12/dist-packages (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.2.2)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (from pandasql) (2.0.44)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pandasql) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy->pandasql) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.17.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("\nEstrutura de df_accounts:")
df_accounts.info()

print("\nPrimeiras 5 linhas de df_cases:")
print(df_cases.head())
# Out:
# Estrutura de df_accounts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1415 entries, 0 to 1414
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   account_sfid          1415 non-null   object
#  1   account_name          1415 non-null   object
#  2   account_created_date  1415 non-null   object
#  3   account_country       1408 non-null   object
#  4   account_industry      1402 non-null   object
# dtypes: object(5)
# memory usage: 55.4+ KB
#
# Primeiras 5 linhas de df_cases:
#                                            case_sfid  \
# 0  c9f05bc582a8abec4c5f1a9385c24a96d86d3f3093c557...
# 1  a8f7c39a437d713e800599205d6cd9319733fd5df18af8...
# 2  654dd0c826e0842cdd030e935aa1e886787cb990b693c2...
# 3  57422ac55031dd6c7acf36a2bc6d74e01e0c0194c61318...
# 4  b88c12d55a7c468c96e48a7693e306e24f44947f5f1e3f...
#
#                                         account_sfid  case_number  \
# 0  58912bf7e5131400adbc1c1521158b7b8cc2f2f3fbd51f...        69908
# 1  3675a0565672bccecbba8a8a102b0482f3c82e6f07443e...        69887
# 2  58912bf7e5131400adbc1c1521158b7b8cc2f2f3fbd51f...        69910
# 3  908d42c9a4e3f4beae8bf394dd2ed82090a219cdf64518...        69905
# 4                                               None        69891
#
#   case_contact_name       case_product case_status case_resolution  \
# 0  Contact_e2737240  Verify Enterprise      Closed            Done
# 1  Contact_20439d47      GVD Perpetual      Closed            Done
# 2  Contact_edf7784e  Verify Enterprise      Closed            Done
# 3  Contact_6f59abbf             Verify      Closed            Done
# 4  Contact_f02dfb7d              Other         New       Undefined
#
#   case_details case_closure case_priority case_severity case_reason  \
# 0        Trial    Undefined        Normal        Medium       Other
# 1        Trial    Undefined        Normal           Low       Other
# 2        Trial    Undefined        Normal           Low       Other
# 3         Full    Undefined        Normal        Medium       Other
# 4    Undefined    Undefined        Normal     Undefined       Other
#
#             case_type case_category case_created_date case_closed_date
# 0  License Activation     Licensing        2025-01-09       2025-01-09
# 1  License Activation     Licensing        2025-01-09       2025-01-09
# 2  License Activation     Licensing        2025-01-09       2025-01-09
# 3  License Activation     Licensing        2025-01-09       2025-01-09
# 4           Undefined     Undefined        2025-01-09             None

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
# Verificar valores nulos
print("\n1. VALORES NULOS:")
print("Accounts - Valores nulos:")
print(df_accounts.isnull().sum())
print("\nCases - Valores nulos:")
print(df_cases.isnull().sum())

# Verificar duplicatas
print("\n2. DUPLICATAS:")
print(f"Accounts duplicados: {df_accounts.duplicated().sum()}")
print(f"Cases duplicados: {df_cases.duplicated().sum()}")

# Estatísticas descritivas
print("\n3. ESTATÍSTICAS DESCRITIVAS - ACCOUNTS:")
print(df_accounts.describe(include='all'))

print("\n4. ESTATÍSTICAS DESCRITIVAS - CASES:")
print(df_cases.describe(include='all'))

# Distribuição de categorias importantes
print("\n5. DISTRIBUIÇÃO DE CATEGORIAS:")
print("Países dos accounts:")
print(df_accounts['account_country'].value_counts().head(10))
# Out:
# 1. VALORES NULOS:
# Accounts - Valores nulos:
# account_sfid             0
# account_name             0
# account_created_date     0
# account_country          7
# account_industry        13
# dtype: int64
#
# Cases - Valores nulos:
# case_sfid               0
# account_sfid         1593
# case_number             0
# case_contact_name       0
# case_product            0
# case_status             0
# case_resolution         0
# case_details            0
# case_closure            0
# case_priority           0
# case_severity           0
# case_reason             0
# case_type               0
# case_category           0
# case_created_date       0
# case_closed_date      942
# dtype: int64
#
# 2. DUPLICATAS:
# Accounts duplicados: 0
# Cases duplicados: 0
#
# 3. ESTATÍSTICAS DESCRITIVAS - ACCOUNTS:
#                                              account_sfid       account_name  \
# count                                                1415               1415
# unique                                               1415               1414
# top     1f6e4aeb836642a07eea6bb5da7ccb3dd5023c23f2ad3c...  Customer_71f8fa02
# freq                                                    1                  2
#
#        account_created_date account_country account_industry
# count                  1415            1408             1402
# unique                 1358              72               22
# top     2022-12-16 19:55:40   United States  Pharmaceuticals
# freq                      6             553              421
#
# 4. ESTATÍSTICAS DESCRITIVAS - CASES:
#                                                 case_sfid  \
# count                                               10000
# unique                                              10000
# top     d1a1ceae99d05f08e05ba74768d9bc181098b4db615c9d...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              account_sfid   case_number  \
# count                                                8407  10000.000000
# unique                                               1415           NaN
# top     87b5772b6964f23ef7db8085e8f91c41937979575f8afd...           NaN
# freq                                                 1650           NaN
# mean                                                  NaN  64884.845700
# std                                                   NaN   2914.373454
# min                                                   NaN  59745.000000
# 25%                                                   NaN  62388.750000
# 50%                                                   NaN  64890.500000
# 75%                                                   NaN  67406.250000
# max                                                   NaN  69911.000000
#
#        case_contact_name case_product case_status case_resolution  \
# count              10000        10000       10000           10000
# unique              1654           72           9               9
# top     Contact_f02dfb7d          GVD      Closed       Undefined
# freq                1908         2850        7043            4064
# mean                 NaN          NaN         NaN             NaN
# std                  NaN          NaN         NaN             NaN
# min                  NaN          NaN         NaN             NaN
# 25%                  NaN          NaN         NaN             NaN
# 50%                  NaN          NaN         NaN             NaN
# 75%                  NaN          NaN         NaN             NaN
# max                  NaN          NaN         NaN             NaN
#
#        case_details case_closure case_priority case_severity case_reason  \
# count         10000        10000         10000         10000       10000
# unique           18            1             4             5           5
# top       Undefined    Undefined        Normal        Medium       Other
# freq           4591        10000          9811          4078        9995
# mean            NaN          NaN           NaN           NaN         NaN
# std             NaN          NaN           NaN           NaN         NaN
# min             NaN          NaN           NaN           NaN         NaN
# 25%             NaN          NaN           NaN           NaN         NaN
# 50%             NaN          NaN           NaN           NaN         NaN
# 75%             NaN          NaN           NaN           NaN         NaN
# max             NaN          NaN           NaN           NaN         NaN
#
#         case_type case_category case_created_date case_closed_date
# count       10000         10000             10000             9058
# unique         29             7               378              371
# top     Undefined     Licensing        2024-09-05       2024-09-05
# freq         3728          3847                68               60
# mean          NaN           NaN               NaN              NaN
# std           NaN           NaN               NaN              NaN
# min           NaN           NaN               NaN              NaN
# 25%           NaN           NaN               NaN              NaN
# 50%           NaN           NaN               NaN              NaN
# 75%           NaN           NaN               NaN              NaN
# max           NaN           NaN               NaN              NaN
#
# 5. DISTRIBUIÇÃO DE CATEGORIAS:
# Países dos accounts:
# account_country
# United States     553
# China              73
# Canada             68
# India              60
# United Kingdom     51
# Germany            49
# Spain              47
# South Korea        45
# France             33
# Brazil             28
# Name: count, dtype: int64

# %%
sql_query = """
SELECT
    t1.account_sfid,
    t1.account_country,
    t1.account_industry,
    t2.case_number,
    t2.case_product,
    t2.case_status,
    t2.case_priority,
    t2.case_created_date,
    t2.case_closed_date,
    -- Derivando uma Métrica (KPI): O tempo de resolução em dias
    -- SQLite (usado pelo pandasql) não tem DATEDIFF.
    -- Para calcular a diferença de datas, faremos isso no Pandas após o JOIN.
    -- Vamos primeiro selecionar todos os dados importantes:
    t2.case_sfid
FROM
    df_accounts t1  -- 't1' é o DataFrame df_accounts
INNER JOIN
    df_cases t2     -- 't2' é o DataFrame df_cases
ON
    t1.account_sfid = t2.account_sfid
WHERE
    t2.case_status = 'Closed'; -- Filtra apenas casos fechados para medir o tempo de resolução
"""

df_joined = pysqldf(sql_query)

print("\nDataFrame com Junção (JOIN) e Filtragem concluídas (Primeiras 5 linhas):")
print(df_joined.head())
# Out:
# DataFrame com Junção (JOIN) e Filtragem concluídas (Primeiras 5 linhas):
#                                         account_sfid account_country  \
# 0  58912bf7e5131400adbc1c1521158b7b8cc2f2f3fbd51f...   United States
# 1  3675a0565672bccecbba8a8a102b0482f3c82e6f07443e...           China
# 2  58912bf7e5131400adbc1c1521158b7b8cc2f2f3fbd51f...   United States
# 3  908d42c9a4e3f4beae8bf394dd2ed82090a219cdf64518...  United Kingdom
# 4  1a07fea194096dc37843674e6441e749bf468e63d673f3...        Slovenia
#
#   account_industry  case_number       case_product case_status case_priority  \
# 0  Pharmaceuticals        69908  Verify Enterprise      Closed        Normal
# 1  Pharmaceuticals        69887      GVD Perpetual      Closed        Normal
# 2  Pharmaceuticals        69910  Verify Enterprise      Closed        Normal
# 3  Pharmaceuticals        69905             Verify      Closed        Normal
# 4            Other        69896  Verify Enterprise      Closed        Normal
#
#   case_created_date case_closed_date  \
# 0        2025-01-09       2025-01-09
# 1        2025-01-09       2025-01-09
# 2        2025-01-09       2025-01-09
# 3        2025-01-09       2025-01-09
# 4        2025-01-09       2025-01-09
#
#                                            case_sfid
# 0  c9f05bc582a8abec4c5f1a9385c24a96d86d3f3093c557...
# 1  a8f7c39a437d713e800599205d6cd9319733fd5df18af8...
# 2  654dd0c826e0842cdd030e935aa1e886787cb990b693c2...
# 3  57422ac55031dd6c7acf36a2bc6d74e01e0c0194c61318...
# 4  7201ca1fa40a8466c801b9428fad499c979561e2e8463f...

# %%
#Eficiência por indústria
sql_metrics2 = """
SELECT
    t1.account_industry,
    COUNT(t2.case_sfid) as total_cases,
    SUM(CASE WHEN t2.case_priority = 'High' THEN 1 ELSE 0 END) as high_priority_cases,
    AVG((julianday(t2.case_closed_date) - julianday(t2.case_created_date))) as avg_resolution_days
FROM
    df_accounts t1
INNER JOIN
    df_cases t2 ON t1.account_sfid = t2.account_sfid
WHERE
    t2.case_status = 'Closed'
GROUP BY
    t1.account_industry
HAVING
    total_cases > 5  -- Filtra indústrias com pelo menos 5 casos
ORDER BY
    avg_resolution_days DESC
"""

df_metrics2 = pysqldf(sql_metrics2)
print("\nMétricas por Indústria (eficência de resolução):")
print(df_metrics2.head(10))
# Out:
# Métricas por Indústria (eficência de resolução):
#                 account_industry  total_cases  high_priority_cases  \
# 0                           None           29                    0
# 1                     Financials           38                    0
# 2                Pharmaceuticals         2160                    0
# 3  Household & Personal Products          360                    0
# 4                      Chemicals          101                    0
# 5                      Materials           38                    0
# 6       Packaging and Containers         1006                    2
# 7                       Printing         1038                    0
# 8  Advertising & Branding Agency          436                    0
# 9                          Other          240                    0
#
#    avg_resolution_days
# 0            24.241379
# 1             8.526316
# 2             7.203704
# 3             7.188889
# 4             7.148515
# 5             6.789474
# 6             6.008946
# 7             5.922929
# 8             5.864679
# 9             4.900000

# %%
##Cálculo da Métrica (KPI) - Tempo de Resolução
df_joined['case_created_date'] = pd.to_datetime(df_joined['case_created_date'])
df_joined['case_closed_date'] = pd.to_datetime(df_joined['case_closed_date'])

df_joined['resolution_time_days'] = (
    df_joined['case_closed_date'] - df_joined['case_created_date']
).dt.days

print("\nDataFrame final com a métrica 'resolution_time_days' calculada:")
print(df_joined[['account_country', 'case_product', 'resolution_time_days']].head())
# Out:
# DataFrame final com a métrica 'resolution_time_days' calculada:
#   account_country       case_product  resolution_time_days
# 0   United States  Verify Enterprise                     0
# 1           China      GVD Perpetual                     0
# 2   United States  Verify Enterprise                     0
# 3  United Kingdom             Verify                     0
# 4        Slovenia  Verify Enterprise                     0

# %%
##Criação de Visualizações
import matplotlib.pyplot as plt
import seaborn as sns

# Calcula o tempo médio de resolução por produto
avg_resolution_by_product = df_joined.groupby('case_product')['resolution_time_days'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=avg_resolution_by_product.index, y=avg_resolution_by_product.values, palette="viridis")
plt.title('Tempo Médio de Resolução de Casos (em dias) por Produto')
plt.xlabel('Produto')
plt.ylabel('Média de Dias para Resolução')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4050982897.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_resolution_by_product.index, y=avg_resolution_by_product.values, palette="viridis")

# %%
# Visualização 2: Distribuição de casos por prioridade
plt.figure(figsize=(10, 6))
priority_counts = df_cases['case_priority'].value_counts()
plt.pie(priority_counts.values, labels=priority_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99'])
plt.title('Distribuição de Casos por Prioridade')
plt.show()

# Visualização 3: Top 10 países com mais casos
plt.figure(figsize=(12, 6))
country_cases = df_joined['account_country'].value_counts().head(10)
sns.barplot(x=country_cases.values, y=country_cases.index, palette="rocket")
plt.title('Top 10 Países com Mais Casos de Suporte')
plt.xlabel('Número de Casos')
plt.ylabel('País')
plt.tight_layout()
plt.show()

# Visualização 4: Tempo de resolução por prioridade
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_joined, x='case_priority', y='resolution_time_days', palette="Set2")
plt.title('Tempo de Resolução por Prioridade do Caso')
plt.xlabel('Prioridade')
plt.ylabel('Dias para Resolução')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3064720120.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_cases.values, y=country_cases.index, palette="rocket")
# /tmp/ipython-input-3064720120.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_joined, x='case_priority', y='resolution_time_days', palette="Set2")

# %%
# Cálculos para insights

# Insight 1: Produto com maior tempo de resolução
slowest_product = df_joined.groupby('case_product')['resolution_time_days'].mean().idxmax()
slowest_time = df_joined.groupby('case_product')['resolution_time_days'].mean().max()

print(f"1. PRODUTO COM MAIOR TEMPO DE RESOLUÇÃO:")
print(f"   • {slowest_product}: {slowest_time:.1f} dias em média")
print(f"   • Insight: Este produto pode ter problemas complexos ou falta de documentação adequada")

# Insight 2: País com casos mais demorados
slowest_country = df_joined.groupby('account_country')['resolution_time_days'].mean().idxmax()
slowest_country_time = df_joined.groupby('account_country')['resolution_time_days'].mean().max()

print(f"\n2. PAÍS COM CASOS MAIS DEMORADOS:")
print(f"   • {slowest_country}: {slowest_country_time:.1f} dias em média")
print(f"   • Insight: Pode haver barreiras de idioma, fuso horário ou falta de recursos locais")

# Insight 3: Comparação de eficiência por prioridade
priority_efficiency = df_joined.groupby('case_priority')['resolution_time_days'].mean()
print(f"\n3. EFICIÊNCIA POR PRIORIDADE:")
for priority, time in priority_efficiency.items():
    print(f"   • {priority}: {time:.1f} dias")

# Insight 4: Volume vs. Tempo de Resolução
case_volume_by_product = df_joined['case_product'].value_counts()
resolution_by_product = df_joined.groupby('case_product')['resolution_time_days'].mean()

print(f"\n4. RELAÇÃO ENTRE VOLUME E TEMPO DE RESOLUÇÃO:")
for product in case_volume_by_product.index[:5]:
    volume = case_volume_by_product[product]
    resolution = resolution_by_product[product]
    print(f"   • {product}: {volume} casos, {resolution:.1f} dias médios")
# Out:
# 1. PRODUTO COM MAIOR TEMPO DE RESOLUÇÃO:
#    • Compliance Add-On: 25.0 dias em média
#    • Insight: Este produto pode ter problemas complexos ou falta de documentação adequada
#
# 2. PAÍS COM CASOS MAIS DEMORADOS:
#    • Pakistan: 39.0 dias em média
#    • Insight: Pode haver barreiras de idioma, fuso horário ou falta de recursos locais
#
# 3. EFICIÊNCIA POR PRIORIDADE:
#    • High: 1.5 dias
#    • Normal: 5.6 dias
#    • Urgent: 10.3 dias
#    • not_priority: 1.5 dias
#
# 4. RELAÇÃO ENTRE VOLUME E TEMPO DE RESOLUÇÃO:
#    • GVD: 2626 casos, 7.3 dias médios
#    • Not a Support Case: 1001 casos, 0.6 dias médios
#    • Verify: 963 casos, 7.5 dias médios
#    • GVW: 795 casos, 6.2 dias médios
#    • Esko: 345 casos, 6.4 dias médios
